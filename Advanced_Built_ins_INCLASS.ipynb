# %% [markdown]
# # Map, Filter, Reduce, Lambda & Recursion

# %% [markdown]
# ## Tasks Today:
#
# 1) <b>Lambda Functions</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Syntax <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Saving to a Variable <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Multiple Inputs <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Passing a Lambda into a Function <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Returning a Lambda from a Function <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) In-Class Exercise #1 <br>
# 2) <b>Map</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Syntax <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Using Lambda's with Map <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) In-Class Exercise #2 <br>
# 3) <b>Filter</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Syntax <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Using Lambda's with Filter <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) In-Class Exercise #3 <br>
# 4) <b>Reduce</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Syntax <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Using Lambda's with Reduce <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) In-Class Exercise #4 <br>
# 5) <b>Recursion</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Implementing a Base <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Writing a Factorial Function <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) In-Class Exercise #5 <br>
# 6) <b>Generators & Iterators</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Yield Keyword <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Inifinite Generator <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) In-Class Exercise #6 <br>
# 7) <b>Exercises</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Exercise #1 - Filtering Empty Strings <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Exercise #2 - Sorting with Last Name <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Exercise #3 - Conversion to Farhenheit <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Exercise #4 - Fibonacci Sequence <br>

# %% [markdown]
# ## Lambda Functions <br>
# <p>Lambda functions... or "Anonymous Functions" are referring to inline functions with no name. The keyword lambda denotes the no name function, and executes within a single line. Without saving it to a variable; however, it is not able to be used, unless passed in either as a paramater or within list comprehension.<br>Written as "(keyword lambda) (one or more inputs) (colon) (function to be executed)"</p>

# %% [markdown]
# #### Syntax

# %%
def addTwo(x):
    return x + 2

print(addTwo(4))

#syntax --> lambda input: input codeblock
                    #or
            #lambda parameters: execution
print((lambda x: x + 2)(4))

# %% [markdown]
# #### Saving to a Variable

# %%
f_test = lambda x: x + 2
f_test(4)

# %% [markdown]
# #### Multiple Inputs

# %%
print((lambda x, y, z: x * y * z)(2,4,5))
# Out:
# 40

# %% [markdown]
# #### Passing a Lambda into a Function

# %%
def idk(func, num):
    return func(num)
    
idk(lambda x: x*x, 2)
# Out:
# 4

# %% [markdown]
# #### Returning a Lambda from a Function

# %%
# regular func definition
def mult_test(num):
    return num * 4

# func w/i a func
def returnFunc():
    def mult(num):
        return num * 2
    return mult
f_return = returnFunc()
print(returnFunc())
print(f_return(5))

def test(): # setting up an example of a closure
    names = [] #this is an example of a protected/private variable
    s = lambda name: names.append(name)
    t = lambda : print(names)
    return s, t

addNames, printInfo = test() #This is an example of destructuring
addNames('Brendan')
# printInfo('asdf')
addNames('Brandt')
addNames('Rachel')
printInfo()

# returning a lambda from a reg func

def returnLamb(b, c):
    return lambda d, a : d + a + b + c
r_lamb = returnLamb(2, 3)
print(type(r_lamb))
print(r_lamb(4, 1))
# Out:
# <function returnFunc.<locals>.mult at 0x7fb3d7842040>
# 10
# ['Brendan', 'Brandt', 'Rachel']
# <class 'function'>
# 10

# %% [markdown]
# #### If Statements within Lambdas

# %%
# NOT if, elif, else
# it's if, else
#syntax --> lambda x: True if (condition) else False

f_condition = lambda num : num * 2 if num > 10 else num - 2
print(f_condition(8))
print(f_condition(34))
print(f_condition(3))


# nesting in the else statement to achieve elif effect:
#     lambda x: x * 10 if x < 2 else (x**2 if x < 5 else x **9)

# %% [markdown]
# #### In-Class Exercise #1 <br>
# <p>Write an anonymous function that cubes the arguments passed in and assign the anonymous function to a variable 'f'.</p>

# %%
def cubed(num):
    return num
    
f = lambda x: x**3
print(f(3))
# Out:
# 27

# %% [markdown]
# ## Map <br>
# <p>The map function allows you to iterate over an entire list while running a function on each item of the list. This is why the map function works well with lambda's, because it simplifies things and you write less lines of code.<br>The syntax for a map function is "map(function to be used, list to be used)"<br>However, you must be careful, as the map function returns a map object, not a list. To turn it into a list we use the list() type conversion.</p>

# %% [markdown]
# #### Syntax

# %%
# map(function, iterable- list, dict, tuple, set)
# normally use of a pre-defined function BUT it can also be a lambda
# let's start with a list and square all the numbers

numlist = [4, 11, 56, 2, 15, 8]

#pre-defined ex
def squared(num):
    return num ** 2

# for n in range(len(numlist)):
#     numlist[n] = squared(numlist[n])
# print(numlist)

# with a list comp
next_nums = [n**2 for n in numlist]
print(next_nums)
print(numlist)



#finally, let's look at the map funciton
#1st, with the pre-defined function

list(map(squared, numlist)) #MOST common use case!

#uncommon use case:
for m in map(squared, numlist):
    print(m)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# #### Using Lambda's with Map

# %%
list(map(lambda x: x**2, numlist))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/g6/6_fkpzdx0qzg859w55t36_h80000gq/T/ipykernel_80718/2972963174.py in <module>
# ----> 1 list(map(nums,my_list))
#       2
#       3 for m in map(nums, my_list):
#       4     print(m)
#
# /var/folders/g6/6_fkpzdx0qzg859w55t36_h80000gq/T/ipykernel_80718/256215409.py in nums(list)
#       2 my_list = [1,2,3,4,5,6]
#       3 def nums(list):
# ----> 4     for i in (list):
#       5         print(i)
#       6
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# #### In-Class Exercise #2 <br>
# <p>Use the map function to double each number and minus it by one in the list by using a lambda function</p>

# %%
my_list1 = [1,2,3,4,5]

# def random_fun(lists):
    
    
# random_fun(my_rlist)

list(map(lambda x: x * 2 - 1, my_list1))
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# ## Filter() <br>
# <p>Filter's are similar to the map function, where you're able to pass a function argument and a list argument and filter out something from the list based on the conditions passed. Similar to the map function, it returns a filter object, so you need to type convert it to a list()</p>

# %% [markdown]
# #### Syntax

# %%
# filter(func,iter)

som_nums = [1,2,3,4,5,]
def filtOdds(num):
    if num % 2 == 0:
        return True
    return False

list(filter(filtOdds,som_nums))

names = ["Monique", "anna", "Hannah"]

def a_names(name):
    if name[0].lower() == "a":
        return True
    else:
        return False
    
list(filter(a_names,names))
# Out:
# ['anna']

# %% [markdown]
# #### Using Lambda's with Filter()

# %%
saved_filter = list(filter(lambda name: name[0].lower() == "a", names))
print(saved_filter)
# Out:
# ['anna']

# %% [markdown]
# #### In-Class Exercise #3 <br>
# <p>Filter out all the numbers that are below the mean of the list.<br><b>Hint: Import the 'statistics' module</b></p>

# %%
from statistics import mean

stat_list = [1, 1, 3, 5, 88, 95, 43, 101]

# saved_filters = list(filter(lambda name: , stat_list))
print(mean(stat_list))

# means(stat_list)
# Out:
# 42.125

# %% [markdown]
# ## Reduce() <br>
# <p>Be very careful when using this function, as of Python 3 it's been moved to the 'functools' library and no longer is a built-in function.<br>The creator of Python himself, says to just use a for loop instead.</p>

# %% [markdown]
# #### Syntax

# %%
from functools import reduce

# --> reduce(func, iter)

#whole point is to aggregate all values in a list to one value --> min(), max(), sum()
#func takes in 2 parameters and returns 1
som_nums = [1, 2, 3, 4, 5]

def addNums(num1, num2):
    return num1 + num2

result_add = reduce(addNums, som_nums)


def subNums(num1, num2):
    return num1 - num2

result_sub2 = reduce(subNums, som_nums)
print(result_add)
print(result_sub2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/g6/6_fkpzdx0qzg859w55t36_h80000gq/T/ipykernel_80718/4151044659.py in <module>
#       9     return num1 + nums2
#      10
# ---> 11 result_add = reduce(addNums, stat_list)
#      12 print(result_add)
#
# /var/folders/g6/6_fkpzdx0qzg859w55t36_h80000gq/T/ipykernel_80718/4151044659.py in addNums(num1, num2)
#       7
#       8 def addNums(num1, num2):
# ----> 9     return num1 + nums2
#      10
#      11 result_add = reduce(addNums, stat_list)
#
# NameError: name 'nums2' is not defined

# %% [markdown]
# #### Using Lambda's with Reduce()

# %%
result_lamb = reduce(lambda x, y: x + y, som_nums)
print(result_lamb)

# %% [markdown]
# #### In-Class Exercise #4 <br>
# <p>Use the reduce function to multiply the numbers in the list below together with a lambda function.</p>

# %% [markdown]
# ## Recursion <br>
# <p>Recursion means that a function is calling itself, so it contanstly executes until a base case is reached. It will then push the returning values back up the chain until the function is complete. A prime example of recursion is computing factorials... such that 5! (factorial) is 5*4*3*2*1 which equals 120.</p>

# %% [markdown]
# #### Implementing a Base Case

# %%
def addNums(num):
    if num >= 10:
        print('addNums(10)= 10')
        return num
    else:
        print(f"addNums({num}) = {num} + addNums({num+1})")
        return num + addNums(num+1)
    
addNums(1)

# addNums(1) = 1 + addNums(2)
# addNums(2) = 2 + addNums(3)
# addNums(3) = 3 + addNums(4)
# addNums(4) = 4 + addNums(5)
# addNums(5) = 5 + addNums(6)
# addNums(6) = 6 + addNums(7)
# addNums(7) = 7 + addNums(8)
# addNums(8) = 8 + addNums(9)  --> addNums(9) is now 9! so we add 8 to that!
# addNums(9) = 9 + addNums(10) --> addNums(10) is now 10! so we add 9 to that!
# addNums(10)= 10        #We finally hit our base case- time to go back down the chain!

# %% [markdown]
# #### Writing a Factorial Function

# %%
# 5! (factorial) is 5*4*3*2*1 which equals 120

#while loop version
def factor(num):
    count = 1
    while num >=1:
        count = num * count
        num -= 1
    return count


def factorial(num):
    if num <=1:
        return 1
    else:
        return num * factorial(num - 1)
print(factor(5))
print(factorial(5))

# %% [markdown]
# #### In-Class Exercise #5 <br>
# <p>Write a recursive function that subtracts all numbers to the argument given.</p>

# %%
#See above with a minus sign!!!

# %% [markdown]
# ## Generators <br>
# <p>Generators are a type of iterable, like lists or tuples. They do not allow indexing, but they can still be iterated through with for loops. They are created using functions and the yield statement.</p>

# %% [markdown]
# #### Yield Keyword <br>
# <p>The yield keyword denotes a generator, it doesn't return so it won't leave the function and reset all variables in the function scope, instead it yields the number back to the caller.</p>

# %%
# Is just like return, except it keeps returning, unlike return where it stops a code, yield doesnt


# range(1,10)
print(range(1,10))
print(type(range(1,10)))
# help(range)

#Yield keyword is just like return. . . EXCEPT it denotes a generator, aka it keeps returning
def my_range(start, stop, step):
    while start < stop:
        yield start
        start += step
# my_range(2, 22, 2)

for i in my_range(5, 50, 5):
    print(i)
# Out:
# range(1, 10)
# <class 'range'>
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45

# %% [markdown]
# #### Infinite Generator

# %%
# bad, never create infinite loops

# %% [markdown]
# #### In-Class Exercise #6 <br>
# <p>Create a generator that takes a number argument and yields that number squared, then prints each number squared until zero is reached.</p>

# %%
def squared(start):
    while start>0:
        yield start**2
        start -=1
        
for i in squared(5):
    print(i)
# Out:
# 25
# 16
# 9
# 4
# 1

# %% [markdown]
# # Exercises

# %% [markdown]
# ### Exercise #1 <br>
# <p>Filter out all of the empty strings from the list below</p>
#
# `Output: ['Argentina', 'San Diego', 'Boston', 'New York']`

# %%
places = [" ","Argentina", " ", "San Diego","","  ","","Boston","New York"]


# def idk(list):
#     new_list = []
#     for x in list:
#         if x != " ":
#             new_list.append(x)
            
#         if x != "  ":
#             new_list.append(x)

#     print(new_list)

# idk(places)

# def p_names(lists):
#     if places[0].lower() == "a" or "s" or "b" or "n":
#         return True
#     if i in places == " ":
#         return False
#     else:
#         return False
    
# list(filter(p_names,places))

# list1 = []
# for i in places:
#     if i in places == (' ',''):
#         j = i.replace(' ','')
#         list1.append(j)
    
# print(list1)

list1 = []
for i in places:
    if i.strip():
        list1.append(i)
print(list1)


# new_list = list(filter(None, places))

# new_list = list(filter(lambda x: x != ' ' or '' or '  ', places))

# print(new_list)
# Out:
# ['Argentina', 'San Diego', 'Boston', 'New York']

# %% [markdown]
# ### Exercise #2 <br>
# <p>Write an anonymous function that sorts this list by the last name...<br><b>Hint: Use the ".sort()" method and access the key"</b></p>
#
# `Output: ['Victor aNisimov', 'Gary A.J. Bernstein', 'Joel Carter', 'Andrew P. Garfield', 'David hassELHOFF']`

# %%
author = ["Joel Carter", "Victor aNisimov", "Andrew P. Garfield","David hassELHOFF","Gary A.J. Bernstein"]

# author.sort(key=lambda name: name.split(" ")[-1].lower())
# print(author)

x = sorted(author, key=lambda name: name.split(" ")[-1].lower())
print(x)
# print(author)
# Out:
# ['Victor aNisimov', 'Gary A.J. Bernstein', 'Joel Carter', 'Andrew P. Garfield', 'David hassELHOFF']

# %% [markdown]
# ### Exercise #3 <br>
# <p>Convert the list below from Celsius to Farhenheit, using the map function with a lambda...</p>
#
# `Output: [('Nashua', 89.6), ('Boston', 53.6), ('Los Angelos', 111.2), ('Miami', 84.2)]
# `

# %%
# F = (9/5)*C + 32
places = [('Nashua',32),("Boston",12),("Los Angelos",44),("Miami",29)]

# return a tuple that includes the place name
places1 = list(map(lambda c:  (c[0], (9/5) * c[1]+ 32), places))
print(places1)
# Out:
# [('Nashua', 89.6), ('Boston', 53.6), ('Los Angelos', 111.2), ('Miami', 84.2)]

# %% [markdown]
# ### Exercise #4 <br>
# <p>Write a recursion function to perform the fibonacci sequence up to the number passed in.</p>
#
# `Output for fib(5) =>
# Iteration 0: 1
# Iteration 1: 1
# Iteration 2: 2
# Iteration 3: 3
# Iteration 4: 5
# Iteration 5: 8`

# %%
# def addNums1(num):
#     if num >= 5:
#         print('Iteration 5: 8')
#         return num
#     else:
#         print(f"Iteration {num} : {num} + {num+1}")
#         return (addNums(n-1) + aaddNums(n-2))
    
# addNums1(5)

# def fibo(n): #Base case 
#     if n <= 0:
#         print("Iteration 5: 8")
#         return n
    
#     else:
#         print(f"Iteration {n} : {n-1 + n-2}")
#         return(n-1 + n-2)
# fibo(5)

def fibo(n):
    if n in {-1, 6}:  # Base case
        print("Output for fib(5) =>")
        return n 
    else:
        print(f"Iteration {n}: {(n-1) + (n-2)}")
        return fibo(n - 1) + fibo(n - 2)

fibo(5)

# def fibonacci(n):
#     if(n <= 1):
#         print("Output for fib(5) =>")
#         return n
#     else:
#         for i in range(n):
#             print(f"Iteration {n}:{i-1 + n-2}")
#         return(fibonacci(n-1) + fibonacci(n-2))
# #         for i in range(n):
# #             print(f"Iteration {n}:{i}")
# fibonacci(5)
# Out:
# Iteration 5: 7
# Iteration 4: 5
# Iteration 3: 3
# Iteration 2: 1
# Iteration 1: -1
# Iteration 0: -3
# Output for fib(5) =>
# Iteration -2: -7
# Iteration -3: -9
# Iteration -4: -11
# Iteration -5: -13
# Iteration -6: -15
# Iteration -7: -17
# Iteration -8: -19
# Iteration -9: -21
# Iteration -10: -23
# Iteration -11: -25
# Iteration -12: -27
# Iteration -13: -29
# Iteration -14: -31
# Iteration -15: -33
# Iteration -16: -35
# Iteration -17: -37
# Iteration -18: -39
# Iteration -19: -41
# Iteration -20: -43
# Iteration -21: -45
# Iteration -22: -47
# Iteration -23: -49
# Iteration -24: -51
# Iteration -25: -53
# Iteration -26: -55
# Iteration -27: -57
# Iteration -28: -59
# Iteration -29: -61
# Iteration -30: -63
# Iteration -31: -65
# Iteration -32: -67
# Iteration -33: -69
# Iteration -34: -71
# Iteration -35: -73
# Iteration -36: -75
# Iteration -37: -77
# Iteration -38: -79
# Iteration -39: -81
# Iteration -40: -83
# Iteration -41: -85
# Iteration -42: -87
# Iteration -43: -89
# Iteration -44: -91
# Iteration -45: -93
# Iteration -46: -95
# Iteration -47: -97
# Iteration -48: -99
# Iteration -49: -101
# Iteration -50: -103
# Iteration -51: -105
# Iteration -52: -107
# Iteration -53: -109
# Iteration -54: -111
# Iteration -55: -113
# Iteration -56: -115
# Iteration -57: -117
# Iteration -58: -119
# Iteration -59: -121
# Iteration -60: -123
# Iteration -61: -125
# Iteration -62: -127
# Iteration -63: -129
# Iteration -64: -131
# Iteration -65: -133
# Iteration -66: -135
# Iteration -67: -137
# Iteration -68: -139
# Iteration -69: -141
# Iteration -70: -143
# Iteration -71: -145
# Iteration -72: -147
# Iteration -73: -149
# Iteration -74: -151
# Iteration -75: -153
# Iteration -76: -155
# Iteration -77: -157
# Iteration -78: -159
# Iteration -79: -161
# Iteration -80: -163
# Iteration -81: -165
# Iteration -82: -167
# Iteration -83: -169
# Iteration -84: -171
# Iteration -85: -173
# Iteration -86: -175
# Iteration -87: -177
# Iteration -88: -179
# Iteration -89: -181
# Iteration -90: -183
# Iteration -91: -185
# Iteration -92: -187
# Iteration -93: -189
# Iteration -94: -191
# Iteration -95: -193
# Iteration -96: -195
# Iteration -97: -197
# Iteration -98: -199
# Iteration -99: -201
# Iteration -100: -203
# Iteration -101: -205
# Iteration -102: -207
# Iteration -103: -209
# Iteration -104: -211
# Iteration -105: -213
# Iteration -106: -215
# Iteration -107: -217
# Iteration -108: -219
# Iteration -109: -221
# Iteration -110: -223
# Iteration -111: -225
# Iteration -112: -227
# Iteration -113: -229
# Iteration -114: -231
# Iteration -115: -233
# Iteration -116: -235
# Iteration -117: -237
# Iteration -118: -239
# Iteration -119: -241
# Iteration -120: -243
# Iteration -121: -245
# Iteration -122: -247
# Iteration -123: -249
# Iteration -124: -251
# Iteration -125: -253
# Iteration -126: -255
# Iteration -127: -257
# Iteration -128: -259
# Iteration -129: -261
# Iteration -130: -263
# Iteration -131: -265
# Iteration -132: -267
# Iteration -133: -269
# Iteration -134: -271
# Iteration -135: -273
# Iteration -136: -275
# Iteration -137: -277
# Iteration -138: -279
# Iteration -139: -281
# Iteration -140: -283
# Iteration -141: -285
# Iteration -142: -287
# Iteration -143: -289
# Iteration -144: -291
# Iteration -145: -293
# Iteration -146: -295
# Iteration -147: -297
# Iteration -148: -299
# Iteration -149: -301
# Iteration -150: -303
# Iteration -151: -305
# Iteration -152: -307
# Iteration -153: -309
# Iteration -154: -311
# Iteration -155: -313
# Iteration -156: -315
# Iteration -157: -317
# Iteration -158: -319
# Iteration -159: -321
# Iteration -160: -323
# Iteration -161: -325
# Iteration -162: -327
# Iteration -163: -329
# Iteration -164: -331
# Iteration -165: -333
# Iteration -166: -335
# Iteration -167: -337
# Iteration -168: -339
# Iteration -169: -341
# Iteration -170: -343
# Iteration -171: -345
# Iteration -172: -347
# Iteration -173: -349
# Iteration -174: -351
# Iteration -175: -353
# Iteration -176: -355
# Iteration -177: -357
# Iteration -178: -359
# Iteration -179: -361
# Iteration -180: -363
# Iteration -181: -365
# Iteration -182: -367
# Iteration -183: -369
# Iteration -184: -371
# Iteration -185: -373
# Iteration -186: -375
# Iteration -187: -377
# Iteration -188: -379
# Iteration -189: -381
# Iteration -190: -383
# Iteration -191: -385
# Iteration -192: -387
# Iteration -193: -389
# Iteration -194: -391
# Iteration -195: -393
# Iteration -196: -395
# Iteration -197: -397
# Iteration -198: -399
# Iteration -199: -401
# Iteration -200: -403
# Iteration -201: -405
# Iteration -202: -407
# Iteration -203: -409
# Iteration -204: -411
# Iteration -205: -413
# Iteration -206: -415
# Iteration -207: -417
# Iteration -208: -419
# Iteration -209: -421
# Iteration -210: -423
# Iteration -211: -425
# Iteration -212: -427
# Iteration -213: -429
# Iteration -214: -431
# Iteration -215: -433
# Iteration -216: -435
# Iteration -217: -437
# Iteration -218: -439
# Iteration -219: -441
# Iteration -220: -443
# Iteration -221: -445
# Iteration -222: -447
# Iteration -223: -449
# Iteration -224: -451
# Iteration -225: -453
# Iteration -226: -455
# Iteration -227: -457
# Iteration -228: -459
# Iteration -229: -461
# Iteration -230: -463
# Iteration -231: -465
# Iteration -232: -467
# Iteration -233: -469
# Iteration -234: -471
# Iteration -235: -473
# Iteration -236: -475
# Iteration -237: -477
# Iteration -238: -479
# Iteration -239: -481
# Iteration -240: -483
# Iteration -241: -485
# Iteration -242: -487
# Iteration -243: -489
# Iteration -244: -491
# Iteration -245: -493
# Iteration -246: -495
# Iteration -247: -497
# Iteration -248: -499
# Iteration -249: -501
# Iteration -250: -503
# Iteration -251: -505
# Iteration -252: -507
# Iteration -253: -509
# Iteration -254: -511
# Iteration -255: -513
# Iteration -256: -515
# Iteration -257: -517
# Iteration -258: -519
# Iteration -259: -521
# Iteration -260: -523
# Iteration -261: -525
# Iteration -262: -527
# Iteration -263: -529
# Iteration -264: -531
# Iteration -265: -533
# Iteration -266: -535
# Iteration -267: -537
# Iteration -268: -539
# Iteration -269: -541
# Iteration -270: -543
# Iteration -271: -545
# Iteration -272: -547
# Iteration -273: -549
# Iteration -274: -551
# Iteration -275: -553
# Iteration -276: -555
# Iteration -277: -557
# Iteration -278: -559
# Iteration -279: -561
# Iteration -280: -563
# Iteration -281: -565
# Iteration -282: -567
# Iteration -283: -569
# Iteration -284: -571
# Iteration -285: -573
# Iteration -286: -575
# Iteration -287: -577
# Iteration -288: -579
# Iteration -289: -581
# Iteration -290: -583
# Iteration -291: -585
# Iteration -292: -587
# Iteration -293: -589
# Iteration -294: -591
# Iteration -295: -593
# Iteration -296: -595
# Iteration -297: -597
# Iteration -298: -599
# Iteration -299: -601
# Iteration -300: -603
# Iteration -301: -605
# Iteration -302: -607
# Iteration -303: -609
# Iteration -304: -611
# Iteration -305: -613
# Iteration -306: -615
# Iteration -307: -617
# Iteration -308: -619
# Iteration -309: -621
# Iteration -310: -623
# Iteration -311: -625
# Iteration -312: -627
# Iteration -313: -629
# Iteration -314: -631
# Iteration -315: -633
# Iteration -316: -635
# Iteration -317: -637
# Iteration -318: -639
# Iteration -319: -641
# Iteration -320: -643
# Iteration -321: -645
# Iteration -322: -647
# Iteration -323: -649
# Iteration -324: -651
# Iteration -325: -653
# Iteration -326: -655
# Iteration -327: -657
# Iteration -328: -659
# Iteration -329: -661
# Iteration -330: -663
# Iteration -331: -665
# Iteration -332: -667
# Iteration -333: -669
# Iteration -334: -671
# Iteration -335: -673
# Iteration -336: -675
# Iteration -337: -677
# Iteration -338: -679
# Iteration -339: -681
# Iteration -340: -683
# Iteration -341: -685
# Iteration -342: -687
# Iteration -343: -689
# Iteration -344: -691
# Iteration -345: -693
# Iteration -346: -695
# Iteration -347: -697
# Iteration -348: -699
# Iteration -349: -701
# Iteration -350: -703
# Iteration -351: -705
# Iteration -352: -707
# Iteration -353: -709
# Iteration -354: -711
# Iteration -355: -713
# Iteration -356: -715
# Iteration -357: -717
# Iteration -358: -719
# Iteration -359: -721
# Iteration -360: -723
# Iteration -361: -725
# Iteration -362: -727
# Iteration -363: -729
# Iteration -364: -731
# Iteration -365: -733
# Iteration -366: -735
# Iteration -367: -737
# Iteration -368: -739
# Iteration -369: -741
# Iteration -370: -743
# Iteration -371: -745
# Iteration -372: -747
# Iteration -373: -749
# Iteration -374: -751
# Iteration -375: -753
# Iteration -376: -755
# Iteration -377: -757
# Iteration -378: -759
# Iteration -379: -761
# Iteration -380: -763
# Iteration -381: -765
# Iteration -382: -767
# Iteration -383: -769
# Iteration -384: -771
# Iteration -385: -773
# Iteration -386: -775
# Iteration -387: -777
# Iteration -388: -779
# Iteration -389: -781
# Iteration -390: -783
# Iteration -391: -785
# Iteration -392: -787
# Iteration -393: -789
# Iteration -394: -791
# Iteration -395: -793
# Iteration -396: -795
# Iteration -397: -797
# Iteration -398: -799
# Iteration -399: -801
# Iteration -400: -803
# Iteration -401: -805
# Iteration -402: -807
# Iteration -403: -809
# Iteration -404: -811
# Iteration -405: -813
# Iteration -406: -815
# Iteration -407: -817
# Iteration -408: -819
# Iteration -409: -821
# Iteration -410: -823
# Iteration -411: -825
# Iteration -412: -827
# Iteration -413: -829
# Iteration -414: -831
# Iteration -415: -833
# Iteration -416: -835
# Iteration -417: -837
# Iteration -418: -839
# Iteration -419: -841
# Iteration -420: -843
# Iteration -421: -845
# Iteration -422: -847
# Iteration -423: -849
# Iteration -424: -851
# Iteration -425: -853
# Iteration -426: -855
# Iteration -427: -857
# Iteration -428: -859
# Iteration -429: -861
# Iteration -430: -863
# Iteration -431: -865
# Iteration -432: -867
# Iteration -433: -869
# Iteration -434: -871
# Iteration -435: -873
# Iteration -436: -875
# Iteration -437: -877
# Iteration -438: -879
# Iteration -439: -881
# Iteration -440: -883
# Iteration -441: -885
# Iteration -442: -887
# Iteration -443: -889
# Iteration -444: -891
# Iteration -445: -893
# Iteration -446: -895
# Iteration -447: -897
# Iteration -448: -899
# Iteration -449: -901
# Iteration -450: -903
# Iteration -451: -905
# Iteration -452: -907
# Iteration -453: -909
# Iteration -454: -911
# Iteration -455: -913
# Iteration -456: -915
# Iteration -457: -917
# Iteration -458: -919
# Iteration -459: -921
# Iteration -460: -923
# Iteration -461: -925
# Iteration -462: -927
# Iteration -463: -929
# Iteration -464: -931
# Iteration -465: -933
# Iteration -466: -935
# Iteration -467: -937
# Iteration -468: -939
# Iteration -469: -941
# Iteration -470: -943
# Iteration -471: -945
# Iteration -472: -947
# Iteration -473: -949
# Iteration -474: -951
# Iteration -475: -953
# Iteration -476: -955
# Iteration -477: -957
# Iteration -478: -959
# Iteration -479: -961
# Iteration -480: -963
# Iteration -481: -965
# Iteration -482: -967
# Iteration -483: -969
# Iteration -484: -971
# Iteration -485: -973
# Iteration -486: -975
# Iteration -487: -977
# Iteration -488: -979
# Iteration -489: -981
# Iteration -490: -983
# Iteration -491: -985
# Iteration -492: -987
# Iteration -493: -989
# Iteration -494: -991
# Iteration -495: -993
# Iteration -496: -995
# Iteration -497: -997
# Iteration -498: -999
# Iteration -499: -1001
# Iteration -500: -1003
# Iteration -501: -1005
# Iteration -502: -1007
# Iteration -503: -1009
# Iteration -504: -1011
# Iteration -505: -1013
# Iteration -506: -1015
# Iteration -507: -1017
# Iteration -508: -1019
# Iteration -509: -1021
# Iteration -510: -1023
# Iteration -511: -1025
# Iteration -512: -1027
# Iteration -513: -1029
# Iteration -514: -1031
# Iteration -515: -1033
# Iteration -516: -1035
# Iteration -517: -1037
# Iteration -518: -1039
# Iteration -519: -1041
# Iteration -520: -1043
# Iteration -521: -1045
# Iteration -522: -1047
# Iteration -523: -1049
# Iteration -524: -1051
# Iteration -525: -1053
# Iteration -526: -1055
# Iteration -527: -1057
# Iteration -528: -1059
# Iteration -529: -1061
# Iteration -530: -1063
# Iteration -531: -1065
# Iteration -532: -1067
# Iteration -533: -1069
# Iteration -534: -1071
# Iteration -535: -1073
# Iteration -536: -1075
# Iteration -537: -1077
# Iteration -925: -1853
# Iteration -926: -1855
# Iteration -927: -1857
# Iteration -928: -1859
# Iteration -929: -1861
# Iteration -930: -1863
# Iteration -931: -1865
# Iteration -932: -1867
# Iteration -933: -1869
# Iteration -934: -1871
# Iteration -935: -1873
# Iteration -936: -1875
# Iteration -937: -1877
# Iteration -938: -1879
# Iteration -939: -1881
# Iteration -940: -1883
# Iteration -941: -1885
# Iteration -942: -1887
# Iteration -943: -1889
# Iteration -944: -1891
# Iteration -945: -1893
# Iteration -946: -1895
# Iteration -947: -1897
# Iteration -948: -1899
# Iteration -949: -1901
# Iteration -950: -1903
# Iteration -951: -1905
# Iteration -952: -1907
# Iteration -953: -1909
# Iteration -954: -1911
# Iteration -955: -1913
# Iteration -956: -1915
# Iteration -957: -1917
# Iteration -958: -1919
# Iteration -959: -1921
# Iteration -960: -1923
# Iteration -961: -1925
# Iteration -962: -1927
# Iteration -963: -1929
# Iteration -964: -1931
# Iteration -965: -1933
# Iteration -966: -1935
# Iteration -967: -1937
# Iteration -968: -1939
# Iteration -969: -1941
# Iteration -970: -1943
# Iteration -971: -1945
# Iteration -972: -1947
# Iteration -973: -1949
# Iteration -974: -1951
# Iteration -975: -1953
# Iteration -976: -1955
# Iteration -977: -1957
# Iteration -978: -1959
# Iteration -979: -1961
# Iteration -980: -1963
# Iteration -981: -1965
# Iteration -982: -1967
# Iteration -983: -1969
# Iteration -984: -1971
# Iteration -985: -1973
# Iteration -986: -1975
# Iteration -987: -1977
# Iteration -988: -1979
# Iteration -989: -1981
# Iteration -990: -1983
# Iteration -991: -1985
# Iteration -992: -1987
# Iteration -993: -1989
# Iteration -994: -1991
# Iteration -995: -1993
# Iteration -996: -1995
# Iteration -997: -1997
# Iteration -998: -1999
# Iteration -999: -2001
# Iteration -1000: -2003
# Iteration -1001: -2005
# Iteration -1002: -2007
# Iteration -1003: -2009
# Iteration -1004: -2011
# Iteration -1005: -2013
# Iteration -1006: -2015
# Iteration -1007: -2017
# Iteration -1008: -2019
# Iteration -1009: -2021
# Iteration -1010: -2023
# Iteration -1011: -2025
# Iteration -1012: -2027
# Iteration -1013: -2029
# Iteration -1014: -2031
# Iteration -1015: -2033
# Iteration -1016: -2035
# Iteration -1017: -2037
# Iteration -1018: -2039
# Iteration -1019: -2041
# Iteration -1020: -2043
# Iteration -1021: -2045
# Iteration -1022: -2047
# Iteration -1023: -2049
# Iteration -1024: -2051
# Iteration -1025: -2053
# Iteration -1026: -2055
# Iteration -1027: -2057
# Iteration -1028: -2059
# Iteration -1029: -2061
# Iteration -1030: -2063
# Iteration -1031: -2065
# Iteration -1032: -2067
# Iteration -1033: -2069
# Iteration -1034: -2071
# Iteration -1035: -2073
# Iteration -1036: -2075
# Iteration -1037: -2077
# Iteration -1038: -2079
# Iteration -1039: -2081
# Iteration -1040: -2083
# Iteration -1041: -2085
# Iteration -1042: -2087
# Iteration -1043: -2089
# Iteration -1044: -2091
# Iteration -1045: -2093
# Iteration -1046: -2095
# Iteration -1047: -2097
# Iteration -1048: -2099
# Iteration -1049: -2101
# Iteration -1050: -2103
# Iteration -1051: -2105
# Iteration -1052: -2107
# Iteration -1053: -2109
# Iteration -1054: -2111
# Iteration -1055: -2113
# Iteration -1056: -2115
# Iteration -1057: -2117
# Iteration -1058: -2119
# Iteration -1059: -2121
# Iteration -1060: -2123
# Iteration -1061: -2125
# Iteration -1062: -2127
# Iteration -1063: -2129
# Iteration -1064: -2131
# Iteration -1065: -2133
# Iteration -1066: -2135
# Iteration -1067: -2137
# Iteration -1068: -2139
# Iteration -1069: -2141
# Iteration -1070: -2143
# Iteration -1071: -2145
# Iteration -1072: -2147
# Iteration -1073: -2149
# Iteration -1074: -2151
# Iteration -1075: -2153
# Iteration -1076: -2155
# Iteration -1077: -2157
# Iteration -1078: -2159
# Iteration -1079: -2161
# Iteration -1080: -2163
# Iteration -1081: -2165
# Iteration -1082: -2167
# Iteration -1083: -2169
# Iteration -1084: -2171
# Iteration -1085: -2173
# Iteration -1086: -2175
# Iteration -1087: -2177
# Iteration -1088: -2179
# Iteration -1089: -2181
# Iteration -1090: -2183
# Iteration -1091: -2185
# Iteration -1092: -2187
# Iteration -1093: -2189
# Iteration -1094: -2191
# Iteration -1095: -2193
# Iteration -1096: -2195
# Iteration -1097: -2197
# Iteration -1098: -2199
# Iteration -1099: -2201
# Iteration -1100: -2203
# Iteration -1101: -2205
# Iteration -1102: -2207
# Iteration -1103: -2209
# Iteration -1104: -2211
# Iteration -1105: -2213
# Iteration -1106: -2215
# Iteration -1107: -2217
# Iteration -1108: -2219
# Iteration -1109: -2221
# Iteration -1110: -2223
# Iteration -1111: -2225
# Iteration -1112: -2227
# Iteration -1113: -2229
# Iteration -1114: -2231
# Iteration -1115: -2233
# Iteration -1116: -2235
# Iteration -1117: -2237
# Iteration -1118: -2239
# Iteration -1119: -2241
# Iteration -1120: -2243
# Iteration -1121: -2245
# Iteration -1122: -2247
# Iteration -1123: -2249
# Iteration -1124: -2251
# Iteration -1125: -2253
# Iteration -1126: -2255
# Iteration -1127: -2257
# Iteration -1128: -2259
# Iteration -1129: -2261
# Iteration -1130: -2263
# Iteration -1131: -2265
# Iteration -1132: -2267
# Iteration -1133: -2269
# Iteration -1134: -2271
# Iteration -1135: -2273
# Iteration -1136: -2275
# Iteration -1137: -2277
# Iteration -1138: -2279
# Iteration -1139: -2281
# Iteration -1140: -2283
# Iteration -1141: -2285
# Iteration -1142: -2287
# Iteration -1143: -2289
# Iteration -1144: -2291
# Iteration -1145: -2293
# Iteration -1146: -2295
# Iteration -1147: -2297
# Iteration -1148: -2299
# Iteration -1149: -2301
# Iteration -1150: -2303
# Iteration -1151: -2305
# Iteration -1152: -2307
# Iteration -1153: -2309
# Iteration -1154: -2311
# Iteration -1155: -2313
# Iteration -1156: -2315
# Iteration -1157: -2317
# Iteration -1158: -2319
# Iteration -1159: -2321
# Iteration -1160: -2323
# Iteration -1161: -2325
# Iteration -1162: -2327
# Iteration -1163: -2329
# Iteration -1164: -2331
# Iteration -1165: -2333
# Iteration -1166: -2335
# Iteration -1167: -2337
# Iteration -1168: -2339
# Iteration -1169: -2341
# Iteration -1170: -2343
# Iteration -1171: -2345
# Iteration -1172: -2347
# Iteration -1173: -2349
# Iteration -1174: -2351
# Iteration -1175: -2353
# Iteration -1176: -2355
# Iteration -1177: -2357
# Iteration -1178: -2359
# Iteration -1179: -2361
# Iteration -1180: -2363
# Iteration -1181: -2365
# Iteration -1182: -2367
# Iteration -1183: -2369
# Iteration -1184: -2371
# Iteration -1185: -2373
# Iteration -1186: -2375
# Iteration -1187: -2377
# Iteration -1188: -2379
# Iteration -1189: -2381
# Iteration -1190: -2383
# Iteration -1191: -2385
# Iteration -1192: -2387
# Iteration -1193: -2389
# Iteration -1194: -2391
# Iteration -1195: -2393
# Iteration -1196: -2395
# Iteration -1197: -2397
# Iteration -1198: -2399
# Iteration -1199: -2401
# Iteration -1200: -2403
# Iteration -1201: -2405
# Iteration -1202: -2407
# Iteration -1203: -2409
# Iteration -1204: -2411
# Iteration -1205: -2413
# Iteration -1206: -2415
# Iteration -1207: -2417
# Iteration -1208: -2419
# Iteration -1209: -2421
# Iteration -1210: -2423
# Iteration -1211: -2425
# Iteration -1212: -2427
# Iteration -1213: -2429
# Iteration -1214: -2431
# Iteration -1215: -2433
# Iteration -1216: -2435
# Iteration -1217: -2437
# Iteration -1218: -2439
# Iteration -1219: -2441
# Iteration -1220: -2443
# Iteration -1221: -2445
# Iteration -1222: -2447
# Iteration -1223: -2449
# Iteration -1224: -2451
# Iteration -1225: -2453
# Iteration -1226: -2455
# Iteration -1227: -2457
# Iteration -1228: -2459
# Iteration -1229: -2461
# Iteration -1230: -2463
# Iteration -1231: -2465
# Iteration -1232: -2467
# Iteration -1233: -2469
# Iteration -1234: -2471
# Iteration -1235: -2473
# Iteration -1236: -2475
# Iteration -1237: -2477
# Iteration -1238: -2479
# Iteration -1239: -2481
# Iteration -1240: -2483
# Iteration -1241: -2485
# Iteration -1242: -2487
# Iteration -1243: -2489
# Iteration -1244: -2491
# Iteration -1245: -2493
# Iteration -1246: -2495
# Iteration -1247: -2497
# Iteration -1248: -2499
# Iteration -1249: -2501
# Iteration -1250: -2503
# Iteration -1251: -2505
# Iteration -1252: -2507
# Iteration -1253: -2509
# Iteration -1254: -2511
# Iteration -1255: -2513
# Iteration -1256: -2515
# Iteration -1257: -2517
# Iteration -1258: -2519
# Iteration -1259: -2521
# Iteration -1260: -2523
# Iteration -1261: -2525
# Iteration -1262: -2527
# Iteration -1263: -2529
# Iteration -1264: -2531
# Iteration -1265: -2533
# Iteration -1266: -2535
# Iteration -1267: -2537
# Iteration -1268: -2539
# Iteration -1269: -2541
# Iteration -1270: -2543
# Iteration -1271: -2545
# Iteration -1272: -2547
# Iteration -1273: -2549
# Iteration -1274: -2551
# Iteration -1275: -2553
# Iteration -1276: -2555
# Iteration -1277: -2557
# Iteration -1278: -2559
# Iteration -1279: -2561
# Iteration -1280: -2563
# Iteration -1281: -2565
# Iteration -1282: -2567
# Iteration -1283: -2569
# Iteration -1284: -2571
# Iteration -1285: -2573
# Iteration -1286: -2575
# Iteration -1287: -2577
# Iteration -1288: -2579
# Iteration -1289: -2581
# Iteration -1290: -2583
# Iteration -1291: -2585
# Iteration -1292: -2587
# Iteration -1293: -2589
# Iteration -1294: -2591
# Iteration -1295: -2593
# Iteration -1296: -2595
# Iteration -1297: -2597
# Iteration -1298: -2599
# Iteration -1299: -2601
# Iteration -1300: -2603
# Iteration -1301: -2605
# Iteration -1302: -2607
# Iteration -1303: -2609
# Iteration -1304: -2611
# Iteration -1305: -2613
# Iteration -1306: -2615
# Iteration -1307: -2617
# Iteration -1308: -2619
# Iteration -1309: -2621
# Iteration -1310: -2623
# Iteration -1311: -2625
# Iteration -1312: -2627
# Iteration -1313: -2629
# Iteration -1314: -2631
# Iteration -1315: -2633
# Iteration -1316: -2635
# Iteration -1317: -2637
# Iteration -1318: -2639
# Iteration -1319: -2641
# Iteration -1320: -2643
# Iteration -1321: -2645
# Iteration -1322: -2647
# Iteration -1323: -2649
# Iteration -1324: -2651
# Iteration -1325: -2653
# Iteration -1326: -2655
# Iteration -1327: -2657
# Iteration -1328: -2659
# Iteration -1329: -2661
# Iteration -1330: -2663
# Iteration -1331: -2665
# Iteration -1332: -2667
# Iteration -1333: -2669
# Iteration -1334: -2671
# Iteration -1335: -2673
# Iteration -1336: -2675
# Iteration -1337: -2677
# Iteration -1338: -2679
# Iteration -1339: -2681
# Iteration -1340: -2683
# Iteration -1341: -2685
# Iteration -1342: -2687
# Iteration -1343: -2689
# Iteration -1344: -2691
# Iteration -1345: -2693
# Iteration -1346: -2695
# Iteration -1347: -2697
# Iteration -1348: -2699
# Iteration -1349: -2701
# Iteration -1350: -2703
# Iteration -1351: -2705
# Iteration -1352: -2707
# Iteration -1353: -2709
# Iteration -1354: -2711
# Iteration -1355: -2713
# Iteration -1356: -2715
# Iteration -1357: -2717
# Iteration -1358: -2719
# Iteration -1359: -2721
# Iteration -1360: -2723
# Iteration -1361: -2725
# Iteration -1362: -2727
# Iteration -1363: -2729
# Iteration -1364: -2731
# Iteration -1365: -2733
# Iteration -1366: -2735
# Iteration -1367: -2737
# Iteration -1368: -2739
# Iteration -1369: -2741
# Iteration -1370: -2743
# Iteration -1371: -2745
# Iteration -1372: -2747
# Iteration -1373: -2749
# Iteration -1374: -2751
# Iteration -1375: -2753
# Iteration -1376: -2755
# Iteration -1377: -2757
# Iteration -1378: -2759
# Iteration -1379: -2761
# Iteration -1380: -2763
# Iteration -1381: -2765
# Iteration -1382: -2767
# Iteration -1383: -2769
# Iteration -1384: -2771
# Iteration -1385: -2773
# Iteration -1386: -2775
# Iteration -1387: -2777
# Iteration -1388: -2779
# Iteration -1389: -2781
# Iteration -1390: -2783
# Iteration -1391: -2785
# Iteration -1392: -2787
# Iteration -1393: -2789
# Iteration -1394: -2791
# Iteration -1395: -2793
# Iteration -1396: -2795
# Iteration -1397: -2797
# Iteration -1398: -2799
# Iteration -1399: -2801
# Iteration -1400: -2803
# Iteration -1401: -2805
# Iteration -1402: -2807
# Iteration -1403: -2809
# Iteration -1404: -2811
# Iteration -1405: -2813
# Iteration -1406: -2815
# Iteration -1407: -2817
# Iteration -1408: -2819
# Iteration -1409: -2821
# Iteration -1410: -2823
# Iteration -1411: -2825
# Iteration -1412: -2827
# Iteration -1413: -2829
# Iteration -1414: -2831
# Iteration -1415: -2833
# Iteration -1416: -2835
# Iteration -1417: -2837
# Iteration -1418: -2839
# Iteration -1419: -2841
# Iteration -1420: -2843
# Iteration -1421: -2845
# Iteration -1422: -2847
# Iteration -1423: -2849
# Iteration -1424: -2851
# Iteration -1425: -2853
# Iteration -1426: -2855
# Iteration -1427: -2857
# Iteration -1428: -2859
# Iteration -1429: -2861
# Iteration -1430: -2863
# Iteration -1431: -2865
# Iteration -1432: -2867
# Iteration -1433: -2869
# Iteration -1434: -2871
# Iteration -1435: -2873
# Iteration -1436: -2875
# Iteration -1437: -2877
# Iteration -1438: -2879
# Iteration -1439: -2881
# Iteration -1440: -2883
# Iteration -1441: -2885
# Iteration -1442: -2887
# Iteration -1443: -2889
# Iteration -1444: -2891
# Iteration -1445: -2893
# Iteration -1446: -2895
# Iteration -1447: -2897
# Iteration -1448: -2899
# Iteration -1449: -2901
# Iteration -1450: -2903
# Iteration -1451: -2905
# Iteration -1452: -2907
# Iteration -1453: -2909
# Iteration -1454: -2911
# Iteration -1455: -2913
# Iteration -1456: -2915
# Iteration -1457: -2917
# Iteration -1458: -2919
# Iteration -1459: -2921
# Iteration -1460: -2923
# Iteration -1461: -2925
# Iteration -1462: -2927
# Iteration -1463: -2929
# Iteration -1464: -2931
# Iteration -1465: -2933
# Iteration -1466: -2935
# Iteration -1467: -2937
# Iteration -1468: -2939
# Iteration -1469: -2941
# Iteration -1470: -2943
# Iteration -1471: -2945
# Iteration -1472: -2947
# Iteration -1473: -2949
# Iteration -1474: -2951
# Iteration -1475: -2953
# Iteration -1476: -2955
# Iteration -1477: -2957
# Iteration -1478: -2959
# Iteration -1479: -2961
# Iteration -1480: -2963
# Iteration -1481: -2965
# Iteration -1482: -2967
# Iteration -1483: -2969
# Iteration -1484: -2971
# Iteration -1485: -2973
# Iteration -1486: -2975
# Iteration -1487: -2977
# Iteration -1488: -2979
# Iteration -1489: -2981
# Iteration -1490: -2983
# Iteration -1491: -2985
# Iteration -1492: -2987
# Iteration -1493: -2989
# Iteration -1494: -2991
# Iteration -1495: -2993
# Iteration -1496: -2995
# Iteration -1497: -2997
# Iteration -1498: -2999
# Iteration -1499: -3001
# Iteration -1500: -3003
# Iteration -1501: -3005
# Iteration -1502: -3007
# Iteration -1503: -3009
# Iteration -1504: -3011
# Iteration -1505: -3013
# Iteration -1506: -3015
# Iteration -1507: -3017
# Iteration -1508: -3019
# Iteration -1509: -3021
# Iteration -1510: -3023
# Iteration -1511: -3025
# Iteration -1512: -3027
# Iteration -1513: -3029
# Iteration -1514: -3031
# Iteration -1515: -3033
# Iteration -1516: -3035
# Iteration -1517: -3037
# Iteration -1518: -3039
# Iteration -1519: -3041
# Iteration -1520: -3043
# Iteration -1521: -3045
# Iteration -1522: -3047
# Iteration -1523: -3049
# Iteration -1524: -3051
# Iteration -1525: -3053
# Iteration -2872: -5747
# Iteration -2873: -5749
# Iteration -2874: -5751
# Iteration -2875: -5753
# Iteration -2876: -5755
# Iteration -2877: -5757
# Iteration -2878: -5759
# Iteration -2879: -5761
# Iteration -2880: -5763
# Iteration -2881: -5765
# Iteration -2882: -5767
# Iteration -2883: -5769
# Iteration -2884: -5771
# Iteration -2885: -5773
# Iteration -2886: -5775
# Iteration -2887: -5777
# Iteration -2888: -5779
# Iteration -2889: -5781
# Iteration -2890: -5783
# Iteration -2891: -5785
# Iteration -2892: -5787
# Iteration -2893: -5789
# Iteration -2894: -5791
# Iteration -2895: -5793
# Iteration -2896: -5795
# Iteration -2897: -5797
# Iteration -2898: -5799
# Iteration -2899: -5801
# Iteration -2900: -5803
# Iteration -2901: -5805
# Iteration -2902: -5807
# Iteration -2903: -5809
# Iteration -2904: -5811
# Iteration -2905: -5813
# Iteration -2906: -5815
# Iteration -2907: -5817
# Iteration -2908: -5819
# Iteration -2909: -5821
# Iteration -2910: -5823
# Iteration -2911: -5825
# Iteration -2912: -5827
# Iteration -2913: -5829
# Iteration -2914: -5831
# Iteration -2915: -5833
# Iteration -2916: -5835
# Iteration -2917: -5837
# Iteration -2918: -5839
# Iteration -2919: -5841
# Iteration -2920: -5843
# Iteration -2921: -5845
# Iteration -2922: -5847
# Iteration -2923: -5849
# Iteration -2924: -5851
# Iteration -2925: -5853
# Iteration -2926: -5855
# Iteration -2927: -5857
# Iteration -2928: -5859
# Iteration -2929: -5861
# Iteration -2930: -5863
# Iteration -2931: -5865
# Iteration -2932: -5867
# Iteration -2933: -5869
# Iteration -2934: -5871
# Iteration -2935: -5873
# Iteration -2936: -5875
# Iteration -2937: -5877
# Iteration -2938: -5879
# Iteration -2939: -5881
# Iteration -2940: -5883
# Iteration -2941: -5885
# Iteration -2942: -5887
# Iteration -2943: -5889
# Iteration -2944: -5891
# Iteration -2945: -5893
# Iteration -2946: -5895
# Iteration -2947: -5897
# Iteration -2948: -5899
# Iteration -2949: -5901
# Iteration -2950: -5903
# Iteration -2951: -5905
# Iteration -2952: -5907
# Iteration -2953: -5909
# Iteration -2954: -5911
# Iteration -2955: -5913
# Iteration -2956: -5915
# Iteration -2957: -5917
# Iteration -2958: -5919
# Iteration -2959: -5921
# Iteration -2960: -5923
# Iteration -2961: -5925
# Iteration -2962: -5927
# Iteration -2963: -5929
# Iteration -2964: -5931
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /var/folders/g6/6_fkpzdx0qzg859w55t36_h80000gq/T/ipykernel_20306/503762703.py in <module>
#      27         return fibo(n - 1) + fibo(n - 2)
#      28
# ---> 29 fibo(5)
#      30
#      31 # def fibonacci(n):
#
# /var/folders/g6/6_fkpzdx0qzg859w55t36_h80000gq/T/ipykernel_20306/503762703.py in fibo(n)
#      25     else:
#      26         print(f"Iteration {n}: {(n-1) + (n-2)}")
# ---> 27         return fibo(n - 1) + fibo(n - 2)
#      28
#      29 fibo(5)
#
# ... last 1 frames repeated, from the frame below ...
#
# /var/folders/g6/6_fkpzdx0qzg859w55t36_h80000gq/T/ipykernel_20306/503762703.py in fibo(n)
#      25     else:
#      26         print(f"Iteration {n}: {(n-1) + (n-2)}")
# ---> 27         return fibo(n - 1) + fibo(n - 2)
#      28
#      29 fibo(5)
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
